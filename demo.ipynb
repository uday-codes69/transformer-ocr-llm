# %% [markdown]
# # Transformer-based OCR with LLM Refinement
#
# This notebook demonstrates the end-to-end pipeline for processing historical document images.

# %%
from src.pipeline.ocr_pipeline import OCRPipeline
from src.evaluation.metrics import Metrics
from IPython.display import display
from PIL import Image
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.pipeline.ocr_pipeline import OCRPipeline
#       2 from src.evaluation.metrics import Metrics
#       3 from IPython.display import display
#
# File ~/Desktop/transformer-ocr-llm/src/pipeline/ocr_pipeline.py:1
# ----> 1 from src.preprocessing.image_processor import ImagePreprocessor
#       2 from src.models.ocr_model import TRocrModel
#       3 from src.llm_postprocessing.refiner import LLMRefiner
#
# File ~/Desktop/transformer-ocr-llm/src/preprocessing/image_processor.py:1
# ----> 1 import cv2
#       2 import numpy as np
#       3 from PIL import Image
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ## 1. Initialize Pipeline

# %%
pipeline = OCRPipeline(llm_enabled=True)

# %% [markdown]
# ## 2. Run Inference
# Replace `path_to_image.jpg` with a real path to test.

# %%
# image_path = 'sample.jpg'
# results = pipeline.run(image_path)
# print(f"Raw: {results['raw_text']}")
# print(f"Refined: {results['refined_text']}")
